# %% [markdown]
# # Syntax Errors and Exceptions
# -------
# - There are two built in kinds of errors
#     - Syntax Errors
#     - exceptions

# %% [markdown]
# ## 1. Syntax Errors
#     - Syntax errors, also known as `parsing errors`
#     - Syntax errors occur when you make a `typo`

# %% [markdown]
# ### 1.1. Print typo mistake

# %%
print "hello World"
# Out:
#   File "<ipython-input-1-c3365d283592>", line 1
#     print "hello World"
#                       ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("hello World")?

# %% [markdown]
# ### 1.2. for loop typo mistake

# %%
for i in [1,20,34]
print(i)
# Out:
#   File "<ipython-input-3-60d439c83386>", line 1
#     for i in [1,20,34]
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.3. while statement spelling is wrong

# %%
x = int(input('Enter a number: '))

whille x%2 == 0:
    print('You have entered an even number.')
else:
    print ('You have entered an odd number.')
# Out:
#   File "<ipython-input-3-7d22d202663a>", line 3
#     whille x%2 == 0:
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. Exceptions
# - Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it. **Errors detected during execution are called exceptions**

# %% [markdown]
# ### 2.1. ZeroDivisionError

# %%
1/0 # syntax wise correct but mathamatically not possible
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-e22b00e635f9> in <module>
# ----> 1 1/0 # syntax wise correct but mathamatically not possible
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### 2.2. NameError

# %%
4 + a + 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6639d9110bb6> in <module>
# ----> 1 4 + a + 2
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### 2.3. TypeError

# %%
"2" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-192a1d19ca7a> in <module>
# ----> 1 "2" + 2
#
# TypeError: must be str, not int

# %% [markdown]
# ## 2.3.1 StopIteration

# %%
a_str="ram"
a_str_itterator= iter(a_str)

# %%
next(a_str_itterator)
# Out:
# 'r'

# %%
next(a_str_itterator)
# Out:
# 'a'

# %%
next(a_str_itterator)
# Out:
# 'm'

# %%
next(a_str_itterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-fc8e05b89eca> in <module>
# ----> 1 next(a_str_itterator)
#
# StopIteration:

# %% [markdown]
# [For more exception refer python help doc](https://docs.python.org/3/library/exceptions.html#bltin-exceptions)

# %% [markdown]
# ## 3. User Defined Exceptions
# - Catch exceptions with `try-except` clause
#     - Runs the code following **try**
#     - If there’s an error while running code of try cluase, run the code following **except**

# %%
def sqrt(x):
    try:
        print(x ** 0.5)
    except:
        print("please eneter +ve int or float value")

# %%
sqrt(9)
# Out:
# 3.0

# %%
sqrt(-9)
# Out:
# (1.8369701987210297e-16+3j)

# %%
sqrt("python")
# Out:
# please eneter +ve int or float value

# %%
a = "python"

# %%
a ** 0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0546b10aa281> in <module>
# ----> 1 a ** 0.5
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'float'

# %% [markdown]
# ## 4. Link `user defined exception message` with `built-in error codes`

# %%
def sqrt(x):
    if x <0:
        raise NameError("Please enter + ve numeric value")
    else:
        print(x ** 0.5)

# %%
sqrt(9)
# Out:
# 3.0

# %%
sqrt(-9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-01f5efec3bea> in <module>
# ----> 1 sqrt(-9)
#
# <ipython-input-13-92bf24666d64> in sqrt(x)
#       1 def sqrt(x):
#       2     if x <0:
# ----> 3         raise NameError("Please enter + ve numeric value")
#       4     else:
#       5         print(x ** 0.5)
#
# NameError: Please enter + ve numeric value
